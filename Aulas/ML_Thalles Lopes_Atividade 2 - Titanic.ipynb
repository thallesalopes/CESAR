# %%
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv('train.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass  ...       SibSp       Parch        Fare
# count   891.000000  891.000000  891.000000  ...  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642  ...    0.523008    0.381594   32.204208
# std     257.353842    0.486592    0.836071  ...    1.102743    0.806057   49.693429
# min       1.000000    0.000000    1.000000  ...    0.000000    0.000000    0.000000
# 25%     223.500000    0.000000    2.000000  ...    0.000000    0.000000    7.910400
# 50%     446.000000    0.000000    3.000000  ...    0.000000    0.000000   14.454200
# 75%     668.500000    1.000000    3.000000  ...    1.000000    0.000000   31.000000
# max     891.000000    1.000000    3.000000  ...    8.000000    6.000000  512.329200
#
# [8 rows x 7 columns]

# %%
sns.countplot(x='Survived', hue='Sex',data=df)

# %%
sns.histplot(df)

# %%
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fd0d0fff250>,
# ...
#       dtype=object)

# %%
sns.boxplot(data = df)

# %%
sns.boxplot(x='Pclass', y='Age', data=df, palette='winter')

# %%
sns.boxplot(x='Survived', y='Age', data=df, palette='winter')

# %%
df.drop(['Name','Ticket','Cabin'], axis=1, inplace=True)

# %%
df[df.Age.isna()]['Age'] 
df
# Out:
#      PassengerId  Survived  Pclass     Sex  ...  SibSp  Parch     Fare  Embarked
# 0              1         0       3    male  ...      1      0   7.2500         S
# 1              2         1       1  female  ...      1      0  71.2833         C
# 2              3         1       3  female  ...      0      0   7.9250         S
# 3              4         1       1  female  ...      1      0  53.1000         S
# 4              5         0       3    male  ...      0      0   8.0500         S
# ..           ...       ...     ...     ...  ...    ...    ...      ...       ...
# 886          887         0       2    male  ...      0      0  13.0000         S
# 887          888         1       1  female  ...      0      0  30.0000         S
# 888          889         0       3  female  ...      1      2  23.4500         S
# 889          890         1       1    male  ...      0      0  30.0000         C
# 890          891         0       3    male  ...      0      0   7.7500         Q
#
# ...

# %%
  #df[(df['Pclass']==3) & (df['Sex']=='male')]['Age'].mean()

# %%
#df[(df['Pclass']==3) & (df['Sex']=='male') & (df.Age.isna())]['Age']  =
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
#df[(df['Pclass']==3) & (df['Sex']=='male')]['Age'].fillna(value=df[(df['Pclass']==3) & (df['Sex']=='male')]['Age'].mean())
# Out:
# 0      22.000000
# 4      35.000000
# 5      26.507589
# 7       2.000000
# 12     20.000000
#          ...
# 877    19.000000
# 878    26.507589
# 881    33.000000
# 884    25.000000
# 890    32.000000
# Name: Age, Length: 347, dtype: float64

# %%
#df[df['Sex']=='male']['Age'].fillna(value=df[df['Sex']=='male']['Age'].mean(), inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py:4536: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   downcast=downcast,

# %%
df['Age'].fillna(value=df['Age'].mean(), inplace = True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Sex          891 non-null    object
#  4   Age          891 non-null    float64
#  5   SibSp        891 non-null    int64
#  6   Parch        891 non-null    int64
#  7   Fare         891 non-null    float64
#  8   Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(2)
# memory usage: 62.8+ KB

# %%
df.dropna(axis=0, how='any')
# Out:
#      PassengerId  Survived  Pclass     Sex  ...  SibSp  Parch     Fare  Embarked
# 0              1         0       3    male  ...      1      0   7.2500         S
# 1              2         1       1  female  ...      1      0  71.2833         C
# 2              3         1       3  female  ...      0      0   7.9250         S
# 3              4         1       1  female  ...      1      0  53.1000         S
# 4              5         0       3    male  ...      0      0   8.0500         S
# ..           ...       ...     ...     ...  ...    ...    ...      ...       ...
# 886          887         0       2    male  ...      0      0  13.0000         S
# 887          888         1       1  female  ...      0      0  30.0000         S
# 888          889         0       3  female  ...      1      2  23.4500         S
# 889          890         1       1    male  ...      0      0  30.0000         C
# 890          891         0       3    male  ...      0      0   7.7500         Q
#
# ...

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
le.fit(["male", "female"])
list(le.classes_)
# Out:
# ['female', 'male']

# %%
df['Sex_M']=le.transform(df['Sex'])

# %%
df = pd.merge(df,pd.get_dummies(df['Embarked']), left_on=df.index, right_on=pd.get_dummies(df['Embarked']).index)

# %%
df.head()
# Out:
#    key_0  PassengerId  Survived  Pclass     Sex  ...  Embarked  Sex_M  C  Q  S
# 0      0            1         0       3    male  ...         S      1  0  0  1
# 1      1            2         1       1  female  ...         C      0  1  0  0
# 2      2            3         1       3  female  ...         S      0  0  0  1
# 3      3            4         1       1  female  ...         S      0  0  0  1
# 4      4            5         0       3    male  ...         S      1  0  0  1
#
# [5 rows x 14 columns]

# %%
df.drop(['key_0','PassengerId','Embarked','Sex'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    Survived  Pclass   Age  SibSp  Parch     Fare  Sex_M  C  Q  S
# 0         0       3  22.0      1      0   7.2500      1  0  0  1
# 1         1       1  38.0      1      0  71.2833      0  1  0  0
# 2         1       3  26.0      0      0   7.9250      0  0  0  1
# 3         1       1  35.0      1      0  53.1000      0  0  0  1
# 4         0       3  35.0      0      0   8.0500      1  0  0  1

# %%
from sklearn.model_selection import train_test_split

y = df['Survived']
X = df.drop('Survived',axis=1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

# %%
''' from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)
# Out:
#   File "<ipython-input-26-c2ad35b3583f>", line 6
#     X_test_scaled = scaler.transform(X_test)
#
# ^
# SyntaxError: EOF while scanning triple-quoted string literal

# %%
from sklearn.preprocessing import StandardScaler  

X_train_scaled = X_train.copy()
X_test_scaled = X_test.copy()

scaler = StandardScaler()  
scaler.fit(X_train[['Pclass', 'Age', 'SibSp', 'Parch', 'Fare']])

X_train_scaled[['Pclass', 'Age', 'SibSp', 'Parch', 'Fare']] = scaler.transform(X_train[['Pclass', 'Age', 'SibSp', 'Parch', 'Fare']])  
X_test_scaled[['Pclass', 'Age', 'SibSp', 'Parch', 'Fare']] = scaler.transform(X_test[['Pclass', 'Age', 'SibSp', 'Parch', 'Fare']])
X_train_scaled.describe()
# Out:
#              Pclass           Age  ...           Q           S
# count  6.230000e+02  6.230000e+02  ...  623.000000  623.000000
# mean   2.252523e-16 -2.174113e-17  ...    0.088283    0.733547
# std    1.000804e+00  1.000804e+00  ...    0.283933    0.442459
# min   -1.637881e+00 -2.221960e+00  ...    0.000000    0.000000
# 25%   -4.173071e-01 -5.641982e-01  ...    0.000000    0.000000
# 50%    8.032671e-01  2.724309e-02  ...    0.000000    1.000000
# 75%    8.032671e-01  4.344535e-01  ...    0.000000    1.000000
# max    8.032671e-01  3.891324e+00  ...    1.000000    1.000000
#
# [8 rows x 9 columns]
