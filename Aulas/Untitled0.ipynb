# %%
import googlemaps
from datetime import datetime

gmaps = googlemaps.Client(key='AIzaSyDVAps3tV2MUzb_vyCZ5iuZQgm0I3Gz-ls')
directions_results = gmaps.directions('52160070, Brazil', '50040000, Brazil', mode='transit')

steps = directions_results[0]['legs'][0]['steps']
transit = []
for step in steps:
    if step['travel_mode'] == 'TRANSIT':
        transit.append(step)

transf = []

for i in range(len(transit)):
    print('Linha %d' % (i+1))
    bus_number = transit[i]['transit_details']['line']['short_name']
    print(bus_number)
    if i < len(transit)-1:
        transf.append('%s-%s' % (bus_number,transit[i+1]['transit_details']['line']['short_name']))

#for i in (range(len(transit))-1):
#   print('A transferência ocorre entre entre as linhas 'step[i]' e 'step[i+1]')

#import csv
with open('eggs.csv', newline='') as csvfile:
    spamreader = csv.reader(csvfile, delimiter=' ', quotechar='|')
    for row in spamreader:
        print(', '.join(row))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-da4dc884f079> in <module>()
# ----> 1 import googlemaps
#       2 from datetime import datetime
#       3
#       4 gmaps = googlemaps.Client(key='AIzaSyDVAps3tV2MUzb_vyCZ5iuZQgm0I3Gz-ls')
#       5 directions_results = gmaps.directions('52160070, Brazil', '50040000, Brazil', mode='transit')
#
# ModuleNotFoundError: No module named 'googlemaps'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
