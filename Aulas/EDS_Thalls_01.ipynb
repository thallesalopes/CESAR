# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import missingno as msno
import seaborn as sns

# %%
df = pd.read_csv("dataset_avaliacao_faltoso.csv",decimal=",")

# %%
df.head()
# Out:
#                    timestamp  Potencia_Ativa_Gerada  \
# 0  2019-01-01 00:00:00-03:00                557.092
# 1  2019-01-01 00:10:00-03:00                556.622
# 2  2019-01-01 00:20:00-03:00                556.210
# 3  2019-01-01 00:30:00-03:00                555.819
# 4  2019-01-01 00:40:00-03:00                555.431
#
#    Temperatura_Media_Gerador  Potencia_Reativa_Gerada  Pressao_Oleo_Gerador  \
# 0                     61.354                 -492.380                 1.258
# 1                     61.345                 -492.277                 1.257
# 2                     61.336                 -492.186                 1.257
# 3                     61.326                 -492.106                 1.257
# 4                     61.317                 -492.032                 1.257
#
#    Rotacao_Media_Gerador_RPM  Temperatura_Media_Oleo_Gerador  \
# 0                   1090.166                          51.859
# 1                   1090.162                          51.858
# 2                   1090.158                          51.857
# 3                   1090.155                          51.857
# 4                   1090.152                          51.856
#
#    Temperatura_Media_Rolamento_Principal
# 0                                 49.228
# 1                                 49.227
# 2                                 49.227
# 3                                 49.226
# 4                                 49.226

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99999 entries, 0 to 99998
# Data columns (total 8 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   timestamp                              99942 non-null  object
#  1   Potencia_Ativa_Gerada                  99928 non-null  float64
#  2   Temperatura_Media_Gerador              99928 non-null  float64
#  3   Potencia_Reativa_Gerada                99461 non-null  float64
#  4   Pressao_Oleo_Gerador                   99928 non-null  float64
#  5   Rotacao_Media_Gerador_RPM              99928 non-null  float64
#  6   Temperatura_Media_Oleo_Gerador         99414 non-null  float64
#  7   Temperatura_Media_Rolamento_Principal  99928 non-null  float64
# dtypes: float64(7), object(1)
# memory usage: 6.1+ MB

# %%
df.columns
# Out:
# Index(['timestamp', 'Potencia_Ativa_Gerada', 'Temperatura_Media_Gerador',
#        'Potencia_Reativa_Gerada', 'Pressao_Oleo_Gerador',
#        'Rotacao_Media_Gerador_RPM', 'Temperatura_Media_Oleo_Gerador',
#        'Temperatura_Media_Rolamento_Principal'],
#       dtype='object')

# %%
df.shape
# Out:
# (99999, 8)

# %%
features = ['timestamp', 'Potencia_Ativa_Gerada', 'Temperatura_Media_Gerador',
       'Potencia_Reativa_Gerada', 'Pressao_Oleo_Gerador']

df[features].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99999 entries, 0 to 99998
# Data columns (total 5 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   timestamp                  99942 non-null  object
#  1   Potencia_Ativa_Gerada      99928 non-null  float64
#  2   Temperatura_Media_Gerador  99928 non-null  float64
#  3   Potencia_Reativa_Gerada    99461 non-null  float64
#  4   Pressao_Oleo_Gerador       99928 non-null  float64
# dtypes: float64(4), object(1)
# memory usage: 3.8+ MB

# %%
# %matplotlib inline
msno.matrix(df)

# %%
df['Potencia_Ativa_Gerada'].isnull().any()
# Out:
# True

# %%
colunas_missing = []

for col in df.columns:
  if df[col].isnull().any():
    colunas_missing.append(col)

print(colunas_missing)
# Out:
# ['timestamp', 'Potencia_Ativa_Gerada', 'Temperatura_Media_Gerador', 'Potencia_Reativa_Gerada', 'Pressao_Oleo_Gerador', 'Rotacao_Media_Gerador_RPM', 'Temperatura_Media_Oleo_Gerador', 'Temperatura_Media_Rolamento_Principal']

# %%
colunas_missing == df.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True])

# %%
df_dropped = df.dropna(axis = 0, how = 'any')
#df_dropped = df.dropna(axis = 0, how = 'all')

# %matplotlib inline
msno.matrix(df_dropped)

# %%
colunas_missing = []

for col in df_dropped.columns:
  if df_dropped[col].isnull().any():
    colunas_missing.append(col)

print(colunas_missing)
# Out:
# []
